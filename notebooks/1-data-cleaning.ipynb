# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %% [markdown]
# # 0-initial-research

# %% [markdown]
# Dane pochodzą z:
# * https://www.kaggle.com/austinreese/craigslist-carstrucks-data
# * https://github.com/AustinReese/UsedVehicleSearch

# %%
orig = pd.read_csv('../data/raw/vehicles.csv')

# %%
df = orig.copy()

# %%
df.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# 0          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 1          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 2          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 3          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 4          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
#
#   image_url description county state lat long posting_date
# 0       NaN         NaN    NaN    az NaN  NaN          NaN
# 1       NaN         NaN    NaN    ar NaN  NaN          NaN
# 2       NaN         NaN    NaN    fl NaN  NaN          NaN
# 3       NaN         NaN    NaN    ma NaN  NaN          NaN
# 4       NaN         NaN    NaN    nc NaN  NaN          NaN
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (426880, 26)

# %%
sorted(df.columns)
# Out:
# ['VIN',
#  'condition',
#  'county',
#  'cylinders',
#  'description',
#  'drive',
#  'fuel',
#  'id',
#  'image_url',
#  'lat',
#  'long',
#  'manufacturer',
#  'model',
#  'odometer',
#  'paint_color',
#  'posting_date',
#  'price',
#  'region',
#  'region_url',
#  'size',
#  'state',
#  'title_status',
#  'transmission',
#  'type',
#  'url',
#  'year']

# %%
df.dtypes
# Out:
# id                int64
# url              object
# region           object
# region_url       object
# price             int64
# year            float64
# manufacturer     object
# model            object
# condition        object
# cylinders        object
# fuel             object
# odometer        float64
# title_status     object
# transmission     object
# VIN              object
# drive            object
# size             object
# type             object
# paint_color      object
# image_url        object
# description      object
# county          float64
# state            object
# lat             float64
# long            float64
# posting_date     object
# dtype: object

# %% [markdown]
# ## Przykładowe wartości

# %%
df['condition'].unique()
# Out:
# array([nan, 'good', 'excellent', 'fair', 'like new', 'new', 'salvage'],
#       dtype=object)

# %%
df['cylinders'].unique()
# Out:
# array([nan, '8 cylinders', '6 cylinders', '4 cylinders', '5 cylinders',
#        'other', '3 cylinders', '10 cylinders', '12 cylinders'],
#       dtype=object)

# %%
df['drive'].unique()
# Out:
# array([nan, 'rwd', '4wd', 'fwd'], dtype=object)

# %%
df['fuel'].unique()
# Out:
# array([nan, 'gas', 'other', 'diesel', 'hybrid', 'electric'], dtype=object)

# %%
df['drive'].unique()
# Out:
# array([nan, 'rwd', '4wd', 'fwd'], dtype=object)

# %%
df['manufacturer'].unique()
# Out:
# array([nan, 'gmc', 'chevrolet', 'toyota', 'ford', 'jeep', 'nissan', 'ram',
#        'mazda', 'cadillac', 'honda', 'dodge', 'lexus', 'jaguar', 'buick',
#        'chrysler', 'volvo', 'audi', 'infiniti', 'lincoln', 'alfa-romeo',
#        'subaru', 'acura', 'hyundai', 'mercedes-benz', 'bmw', 'mitsubishi',
#        'volkswagen', 'porsche', 'kia', 'rover', 'ferrari', 'mini',
#        'pontiac', 'fiat', 'tesla', 'saturn', 'mercury', 'harley-davidson',
#        'datsun', 'aston-martin', 'land rover', 'morgan'], dtype=object)

# %%
df['model'].unique()
# Out:
# array([nan, 'sierra 1500 crew cab slt', 'silverado 1500', ...,
#        'gand wagoneer', '96 Suburban', 'Paige Glenbrook Touring'],
#       dtype=object)

# %%
df['paint_color'].unique()
# Out:
# array([nan, 'white', 'blue', 'red', 'black', 'silver', 'grey', 'brown',
#        'yellow', 'orange', 'green', 'custom', 'purple'], dtype=object)

# %%
df['size'].unique()
# Out:
# array([nan, 'full-size', 'mid-size', 'compact', 'sub-compact'],
#       dtype=object)

# %%
df['transmission'].unique()
# Out:
# array([nan, 'other', 'automatic', 'manual'], dtype=object)

# %%
df['type'].unique()
# Out:
# array([nan, 'pickup', 'truck', 'other', 'coupe', 'SUV', 'hatchback',
#        'mini-van', 'sedan', 'offroad', 'bus', 'van', 'convertible',
#        'wagon'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([  nan, 2014., 2010., 2020., 2017., 2013., 2012., 2016., 2019.,
#        2011., 1992., 2018., 2004., 2015., 2001., 2006., 1968., 2003.,
#        2008., 2007., 2005., 1966., 2009., 1998., 2002., 1999., 2021.,
#        1997., 1976., 1969., 1995., 1978., 1954., 1979., 1970., 1974.,
#        1996., 1987., 2000., 1955., 1960., 1991., 1972., 1988., 1994.,
#        1929., 1984., 1986., 1989., 1973., 1946., 1933., 1958., 1937.,
#        1985., 1957., 1953., 1942., 1963., 1977., 1993., 1903., 1990.,
#        1965., 1982., 1948., 1983., 1936., 1932., 1951., 1931., 1980.,
#        1967., 1971., 1947., 1981., 1926., 1962., 1975., 1964., 1934.,
#        1952., 1940., 1959., 1950., 1930., 1956., 1922., 1928., 2022.,
#        1901., 1941., 1924., 1927., 1939., 1923., 1949., 1961., 1935.,
#        1918., 1900., 1938., 1913., 1916., 1943., 1925., 1921., 1915.,
#        1945., 1902., 1905., 1920., 1944., 1910., 1909.])

# %%
df['price'].sample(5).head()
# Out:
# 6217      41914
# 278964    21900
# 269882    26995
# 269641    40590
# 331686     4700
# Name: price, dtype: int64

# %%
df['odometer'].sample(5).head()
# Out:
# 162831     37010.0
# 102985     53971.0
# 173782    124615.0
# 400331     50365.0
# 2099         106.0
# Name: odometer, dtype: float64

# %%
df['lat'].sample(5).head()
# Out:
# 171062    39.254962
# 370525    32.790000
# 210349    43.182400
# 85441     41.676091
# 49384     33.779214
# Name: lat, dtype: float64

# %%
df['long'].sample(5).head()
# Out:
# 366036    -98.140442
# 7401     -149.863120
# 336175    -79.970000
# 97329     -82.283186
# 128371   -157.859345
# Name: long, dtype: float64

# %%
df['region'].sample(5).head()
# Out:
# 177458      shreveport
# 334604    philadelphia
# 365193          austin
# 325346           salem
# 54446        san diego
# Name: region, dtype: object

# %% [markdown]
# ## Czyszczenie danych

# %%
df.drop_duplicates(inplace=True)

# %%
to_drop = [
    'VIN',
    'id',
    'image_url',
    'region_url',
    'url',
    'posting_date',
    'state',
    'county',
    'size',
    'description'
]

df.drop(to_drop, axis=1, inplace=True)

# %%
df = df[~df['year'].isna()].copy()
df = df[(2000 <= df['year']) & (df['year'] < 2020)].copy()
df = df[1000 < df['price']].copy()
df = df[0 <= df['odometer']].copy()
df = df[df['title_status'] == 'clean'].copy()
df = df[~df['model'].isna()]

# %%
df['year'] = 2020 - df['year']  # Zmiana lat na wiek

# %%
df['year'].describe()
# Out:
# count    314312.000000
# mean          7.552235
# std           4.873736
# min           1.000000
# 25%           3.000000
# 50%           7.000000
# 75%          11.000000
# max          20.000000
# Name: year, dtype: float64

# %%
df.drop('title_status', axis=1, inplace=True)

# %%
def remove_outliers(df, col):
    k = 1.5
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)    
    iqr = q3 - q1
    df = df[(q1 - k * iqr < df[col]) & (df[col] < q3 + k * iqr)]
    return df

df = remove_outliers(df, 'price')
df = remove_outliers(df, 'odometer')

# %%
def fill_na(df, col):
    if pd.api.types.is_string_dtype(df[col].dtype):
        df.loc[:, col] = df[col].fillna(df[col].mode().to_list()[0])
    else:
        try:
            df.loc[:, col] = df[col].fillna(df[col].median())
        except Exception as e:
            df.loc[:, col] = df[col].fillna(df[col].median().to_list()[0])
    return df

missing = pd.DataFrame(
    data=df.isna().sum() / len(df) * 100, 
    columns=['Pct']
)
missing.sort_values('Pct', ascending=False, inplace=True)

for col in missing[missing['Pct'] > 0].index:
    before = df[col].isna().sum()
    df = fill_na(df, col)
    after = df[col].isna().sum()    
    print(f'{col:<20} {before:<10} {after:<10} {before - after:<10}')
# Out:
# cylinders            126505     0          126505
# condition            118347     0          118347
# drive                90425      0          90425
# paint_color          83749      0          83749
# type                 62129      0          62129
# manufacturer         8802       0          8802
# lat                  3143       0          3143
# long                 3143       0          3143
# fuel                 1409       0          1409
# transmission         1301       0          1301

# %%
print(df.shape)
manu = df[['manufacturer', 'price']].groupby('manufacturer', as_index=False).size()
manu.sort_values('size', inplace=True, ascending=False)

to_small_cat = manu[manu['size'] < manu['size'].quantile(0.25)]['manufacturer'].to_list()
df = df[~df['manufacturer'].isin(to_small_cat)]  # Usuwamy rzadkich producentów

print(to_small_cat)
print(df.shape)
# Out:
# (306612, 15)
# ['porsche', 'saturn', 'alfa-romeo', 'mercury', 'fiat', 'tesla', 'harley-davidson', 'aston-martin', 'land rover', 'ferrari']
# (301875, 15)

# %%
print(df.shape)

valid_model = df[['model', 'price']].groupby('model', as_index=False).size().sort_values('size', ascending=False)
valid_model = valid_model[valid_model['size'] > 100]  # Musi być przynajmniej 100 ogłoszeń danego modelu.
print(valid_model['model'])

df[df['model'].isin(valid_model['model'])].shape

print(df.shape)
# Out:
# (301875, 15)
# 8567                         f-150
# 15624               silverado 1500
# 94                            1500
# 5529                         camry
# 8097                        escape
#                    ...
# 7932                   eos komfort
# 4403                  accord sedan
# 16181        sonata plug-in hybrid
# 6141                      civic si
# 6629     countryman cooper se all4
# Name: model, Length: 503, dtype: object
# (301875, 15)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Brakujące wartości

# %%
missing = pd.DataFrame(
    data=df.isna().sum() / len(df) * 100, 
    columns=['Pct']
)
missing.sort_values('Pct', ascending=False, inplace=True)

# %%
plt.figure(figsize=(4 * (16/9),4), dpi=150)
plt.bar(missing.index, missing['Pct'])
plt.title('Missing values')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig(f'../reports/figures/raw/missing.png')
plt.show()

# %% [markdown]
# ## Zmienna objaśniana

# %%
plt.figure(figsize=(4 * (16/9),4), dpi=150)
plt.hist(df['price'])
plt.title('Histogram of price')
plt.tight_layout()
plt.savefig(f'../reports/figures/raw/price_histogram.png')
plt.show()

# %% [markdown]
# ## Zmienne kategoryczne

# %% [markdown]
# ### Feature cardinality

# %%
categoricals = pd.DataFrame(
    data=df.select_dtypes('object').nunique(),
    columns=['n unique']
)

# %%
categoricals.sort_values('n unique', ascending=False)
# Out:
#               n unique
# model            19043
# region             404
# manufacturer        30
# type                13
# paint_color         12
# cylinders            8
# condition            6
# fuel                 5
# transmission         3
# drive                3

# %% [markdown]
# ## Wykresy słupkowe

# %%
target = 'price'
for col in  df.select_dtypes('object'):
    if col not in ['price', 'description', 'region', 'model', 'status']:
        grouped = df[['price', col]].dropna().groupby(col, as_index=False).mean()
        grouped.sort_values('price', ascending=False, inplace=True)
        plt.figure(figsize=(4 * (16/9),4), dpi=150)
        plt.bar(grouped[col], grouped['price'])
        plt.xticks(rotation=90)
        plt.title(f'{col.capitalize()} vs Mean price')
        plt.tight_layout()
        plt.savefig(f'../reports/figures/raw/{col}_vs_mean_price.png')

# %% [markdown]
# ## Zmienne liczbowe

# %% [markdown]
# ### Wykresy punktowe

# %%
target = 'price'
for col in df.select_dtypes('number'):
    if col != 'price':
        plt.figure(figsize=(4 * (16/9),4), dpi=150)
        plt.scatter(df[target], df[col])
        plt.title(f'{target.capitalize()} vs {col.capitalize()}')
        plt.tight_layout()
        plt.savefig(f'../reports/figures/raw/{col}_vs_price.png')

# %% [markdown]
# ### Statystyki opisowe

# %%
df.select_dtypes('number').describe()
# Out:
#                price           year       odometer            lat  \
# count  263973.000000  263973.000000  263973.000000  263973.000000
# mean    18451.789759       7.562914   94850.803658      38.462846
# std     12058.554609       4.878806   59622.966352       5.623901
# min      1003.000000       1.000000       0.000000     -72.601807
# 25%      7999.000000       3.000000   42207.000000      34.747100
# 50%     15995.000000       7.000000   90960.000000      39.300000
# 75%     26990.000000      11.000000  137280.000000      42.279400
# max     56975.000000      20.000000  280000.000000      82.252826
#
#                 long
# count  263973.000000
# mean      -93.244727
# std        17.513489
# min      -159.719900
# 25%      -105.105500
# 50%       -87.560400
# 75%       -80.420600
# max       167.629911

# %% [markdown]
# ## Zapisanie wyczyszczonego zbioru

# %%
df.head()
# Out:
#     region  price  year manufacturer                        model  condition  \
# 27  auburn  33590   6.0          gmc     sierra 1500 crew cab slt       good
# 28  auburn  22590  10.0    chevrolet               silverado 1500       good
# 30  auburn  30990   3.0       toyota         tundra double cab sr       good
# 31  auburn  15000   7.0         ford                    f-150 xlt  excellent
# 32  auburn  27990   8.0          gmc  sierra 2500 hd extended cab       good
#
#       cylinders fuel  odometer transmission drive    type paint_color     lat  \
# 27  8 cylinders  gas   57923.0        other   4wd  pickup       white  32.590
# 28  8 cylinders  gas   71229.0        other   4wd  pickup        blue  32.590
# 30  8 cylinders  gas   41124.0        other   4wd  pickup         red  32.590
# 31  6 cylinders  gas  128000.0    automatic   rwd   truck       black  32.592
# 32  8 cylinders  gas   68696.0        other   4wd  pickup       black  32.590
#
#        long
# 27 -85.4800
# 28 -85.4800
# 30 -85.4800
# 31 -85.5189
# 32 -85.4800

# %%
df = df[sorted(df.columns)].copy()

# %%
df.shape
# Out:
# (263973, 15)

# %%
df.to_csv('../data/interim/vehicles.csv', index=False)
